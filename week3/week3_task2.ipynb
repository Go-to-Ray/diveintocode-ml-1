# %% [markdown]
# # 【問題1】データセットの取得
# pd.read_csv()を使用して、変数に格納してください。

# %%
import pandas as pd

#dfに格納
df = pd.read_csv("train.csv")
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# # 【問題2】データセット自体の調査
# KaggleのOverviewページや、Dataページの「Data fields」などを読みながら、どのようなデータセットかを説明してください。

# %% [markdown]
# 住宅購入者に夢の家を項目別に説明してもらい、それぞれの家を７９の特徴量で表したデータ

# %% [markdown]
# # 【問題3】データの確認
# データを確認していきます。コードとマークダウンを組み合わせてレポートしてください。
#
#
# 各特徴量がどういったものかを見る。（数値データか文字データなど）
# 今回の目的変数はどの列か確認する。
# 特徴量の平均値と標準偏差、四分位数を一度に表示させる。

# %%
#各特徴量の確認
df.head()
#KaggleのData fieldsより、目的変数はSalePriceであることがわかる。
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#平均、標準偏差、四分位数
value_list = ["mean","std","25%","50%","75%"]
df.describe().loc[value_list]
# Out:
#                Id  MSSubClass  LotFrontage       LotArea  OverallQual  \
# mean   730.500000   56.897260    70.049958  10516.828082     6.099315
# std    421.610009   42.300571    24.284752   9981.264932     1.382997
# 25%    365.750000   20.000000    59.000000   7553.500000     5.000000
# 50%    730.500000   50.000000    69.000000   9478.500000     6.000000
# 75%   1095.250000   70.000000    80.000000  11601.500000     7.000000
#
#       OverallCond    YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# mean     5.575342  1971.267808   1984.865753  103.685262  443.639726
# std      1.112799    30.202904     20.645407  181.066207  456.098091
# 25%      5.000000  1954.000000   1967.000000    0.000000    0.000000
# 50%      5.000000  1973.000000   1994.000000    0.000000  383.500000
# 75%      6.000000  2000.000000   2004.000000  166.000000  712.250000
#
#           ...        WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# ...

# %% [markdown]
# # 【問題4】欠損値への対応
# 欠損値に関して以下のことを行い、レポートしてください。
# 各特徴量の欠損値の有無を確認する。
# 欠損値の確認にはmissingnoというライブラリを活用しましょう。このライブラリにより欠損値の有無が可視化できます。インストールや使い方に関しては以下のページをご覧ください。
#
# ResidentMario/missingno: Missing data visualization module for Python.
#
# 欠損値が何パーセント含まれるかを確認する。
# 5つ以上欠損値がある特徴量（列）は削除する。
# 欠損値があるサンプル（行）は削除する。

# %%
# %matplotlib inline
import missingno as msno
import matplotlib.pyplot as plt
import numpy as np

#欠損値の可視化
msno.bar(df,labels = list(df.keys()))
plt.show()
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /Users/takahashikanato/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
(df.isnull().sum()).shape
# Out:
# (81,)

# %%
#欠損値が何パーセント含まれるか確認
null_ratio = pd.DataFrame({"Total":df.isnull().sum(),"missing_ratio":df.isnull().sum()/df.shape[0]}).sort_values("Total",ascending=False)
#上位５つを表示
null_ratio.head()
# Out:
#              Total  missing_ratio
# PoolQC        1453       0.995205
# MiscFeature   1406       0.963014
# Alley         1369       0.937671
# Fence         1179       0.807534
# FireplaceQu    690       0.472603

# %%
null_count = df.isnull().sum()[df.isnull().sum() < 5]  #欠損値が５つ以上ある特徴量を削除
null_count = null_count.index
df2 = df[null_count].dropna()  #欠損値がある行を削除
df2.head()  #上位５つを表示
# Out:
#    Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0   1          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1   2          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2   3          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3   4          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4   5          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope    ...    EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    Inside       Gtl    ...                0         0           0        0
# 1       FR2       Gtl    ...                0         0           0        0
# 2    Inside       Gtl    ...                0         0           0        0
# 3    Corner       Gtl    ...              272         0           0        0
# 4       FR2       Gtl    ...                0         0           0        0
#
# ...

# %% [markdown]
# # 【問題5】用語の調査
# 以下の２つの単語を知る必要があります。これらを調査してまとめてください。
#
# ・尖度
# ・歪度

# %% [markdown]
# 尖度：分布が正規分布からどれだけ尖っているかを表す統計量。山の尖り度と裾の広がり度を示す。正規分布より尖った分布（データが平均付近に集中し、分布の裾が重い）のときには正の値を、正規分布より扁平な分布のときには負の値をとる。正規分布の場合には0になる。
#
# 歪度：分布が正規分布からどれだけ歪んでいるかを表す統計量で、左右対称性を示す指標のこと。「右裾が長い」もしくは「右に歪んだ」もしくは「左に偏った」分布のときには正の値を、「左裾が長い」もしくは「左に歪んだ」もしくは「右に偏った」分布のときには負の値をとる。

# %% [markdown]
# # 【問題6】分布の確認
# seabornのsns.distplot()を使い目的変数の分布を表示し、「尖度」と「歪度」も算出する。
# 目的変数に対して対数変換を行う。
# 対数変換したものに対して分布を表示し、「尖度」と「歪度」も算出する。
#
# 対数変換の前後での変化を「正規分布」という言葉を含めて説明してください。このように加工することで予測時の精度を上げることができます。

# %%
#目的変数の分布を表示し、尖度と歪度を算出
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
warnings.simplefilter('ignore')

print("尖度：{}".format(df2.SalePrice.kurt()))
print("歪度：{}".format(df2.SalePrice.skew()))
sns.distplot(df2.SalePrice)
plt.show()
# Out:
# 尖度：6.529263049673958
# 歪度：1.8819429948035529

# %%
#対数変換を行い、尖度と歪度を算出
import numpy as np
import matplotlib.pyplot as plt


df2_h = df2.SalePrice.apply(np.log)
sns.distplot(df2_h)
print("尖度：{}".format(df2_h.kurt()))
print("歪度：{}".format(df2_h.skew()))
plt.show()
# Out:
# 尖度：0.806927847502148
# 歪度：0.12131775882415026

# %% [markdown]
# [データの変化の説明]
# 対数変換を行うと、データの分布が変わり、尖度も歪度も０に近づく。
# これはデータの分布が正規分布に近づいたことを表す。

# %% [markdown]
# # 【問題7】相関係数の確認
# 特徴量の確認をしていきます。それぞれに対してマークダウンで説明や考察を書いてください。
#
#
# 相関係数行列のヒートマップを作り、相関係数の高い関係を見つける。
# 目的変数との相関の高い特徴量10個を選び、これらだけの相関係数行列ヒートマップを作る。
# 選んだ10個の特徴量が何か表しているかをKaggleのDataDescriptionの記述を参考に日本語でまとめる。
# 選んだ10個の特徴量の中でお互いの相関係数が高い組み合わせを3つ探し出す。

# %%
#相関係数行列のヒートマップを作り、相関係数の高い関係を見つける。  
plt.subplots(figsize=(14,10))
df2_corr = df2.corr()
sns.heatmap(df2_corr,linewidth = 0.1,linecolor = "white")
plt.show()

# %% [markdown]
# TotalBsmtSFと1stFlrSF、GarageCarsとGarageAreaの相関関係がかなり高いことがわかる。

# %%
#目的変数との相関の高い特徴量10個を選び、これらだけの相関係数行列ヒートマップを作る。
sorted_corr_name = df2_corr.sort_values(by = "SalePrice",ascending=False).SalePrice.keys()[1:11]  #ここの相関係数行列をソートする作業から！
sorted_corr = df[sorted_corr_name]
sorted_corr = sorted_corr.corr()
sns.heatmap(sorted_corr,annot = True)
plt.show()

# %% [markdown]
# GarageCarsとGarageArea、GrLivAreaとTotRmsAbvGrd、TotalBsmtSFと1stFlrSFの３つが相関係数が0.8を超えていて、相関係数が高いことが分かりやすくなった。

# %% [markdown]
# #### 選んだ10個の特徴量が何か表しているかをKaggleのDataDescriptionの記述を参考に日本語でまとめる。
# OverallQual：総合素材と仕上がりの品質
# GrLivArea：地上（地上）のリビングエリアの平方フィート
# GarageCars：車の容量でのガレージのサイズ
# GarageArea：ガレージのサイズ（平方フィート）
# TotalBsmtSF：地下室の総平方フィート
# 1stFlrSF：1階平方フィート
# FullBath：グレード以上のフルバスルーム
# TotRmsAbvGrd：グレード以上の部屋の合計（バスルームは含まれません）
# YearBuilt:元の建設日
# YearRemodAdd:改造日
#
# ここで表示した１０個の特徴量を見てみるといずれも住宅価格に影響を及ぼしそうな項目であることがわかる。

# %% [markdown]
# #### 選んだ10個の特徴量の中でお互いの相関係数が高い組み合わせを3つ探し出す。
# GarageCarsとGarageArea(0.88)
# GrLivAreaとTotRmsAbvGrd(0.83)
# TotalBsmtSFと1stFlrSF（0.82）
